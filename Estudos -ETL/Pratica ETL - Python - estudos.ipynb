# %%
import pandas as pd
import statistics as sts
import seaborn as sbn

# %%
dataset = pd.read_csv('tempo.csv', sep= ';')
dataset
# Out:
#    Aparencia  Temperatura  Umidade       Vento Jogar
# 0        sol           85     85.0       FALSO   nao
# 1        sol           80     90.0  VERDADEIRO   nao
# 2    nublado           83     86.0       FALSO   sim
# 3      chuva           70      NaN       FALSO   sim
# 4      chuva           68     80.0       FALSO   sim
# 5      chuva           65     70.0  VERDADEIRO   nao
# 6      menos           64     65.0  VERDADEIRO   sim
# 7        sol         1220     95.0       FALSO   nao
# 8        sol           69     70.0       FALSO   sim
# 9      chuva           75    200.0         NaN   sim
# 10       sol           75     70.0  VERDADEIRO   sim
# 11   nublado           72     90.0  VERDADEIRO   sim
# 12   nublado           81     75.0       FALSO   sim
# 13     chuva           71     91.0  VERDADEIRO   nao

# %%
#tratando coluna de APARENCIA
dataset.groupby(['Aparencia']).size()
# Out:
# Aparencia
# chuva      5
# menos      1
# nublado    3
# sol        5
# dtype: int64

# %%
#tratando registro "menos" tá fora da regra de negócio, substituindo-o pela moda "sol"
dataset.loc[dataset['Aparencia'] == 'menos', 'Aparencia'] = 'sol'

# %%
dataset.groupby(['Aparencia']).size()
# Out:
# Aparencia
# chuva      5
# nublado    3
# sol        6
# dtype: int64

# %%
#ajustando temperatura
agruptemp = dataset.groupby(['Temperatura']).size()
agruptemp
# Out:
# Temperatura
# 64.0    1
# 65.0    1
# 68.0    1
# 69.0    1
# 70.0    1
# 71.0    1
# 72.0    1
# 73.5    1
# 75.0    2
# 80.0    1
# 81.0    1
# 83.0    1
# 85.0    1
# dtype: int64

# %%
dataset.loc[dataset['Temperatura'] == 1220,'Temperatura'] = 75
dataset
# Out:
#    Aparencia  Temperatura  Umidade       Vento Jogar
# 0        sol         85.0     85.0       FALSO   nao
# 1        sol         80.0     90.0  VERDADEIRO   nao
# 2    nublado         83.0     86.0       FALSO   sim
# 3      chuva         70.0      NaN       FALSO   sim
# 4      chuva         68.0     80.0       FALSO   sim
# 5      chuva         65.0     70.0  VERDADEIRO   nao
# 6        sol         64.0     65.0  VERDADEIRO   sim
# 7        sol         73.5     95.0       FALSO   nao
# 8        sol         69.0     70.0       FALSO   sim
# 9      chuva         75.0    200.0         NaN   sim
# 10       sol         75.0     70.0  VERDADEIRO   sim
# 11   nublado         72.0     90.0  VERDADEIRO   sim
# 12   nublado         81.0     75.0       FALSO   sim
# 13     chuva         71.0     91.0  VERDADEIRO   nao

# %%
#verificando umidade
dataset.isnull().sum()
# Out:
# Aparencia      0
# Temperatura    0
# Umidade        1
# Vento          1
# Jogar          0
# dtype: int64

# %%
#a moda é 70.0
dataset.groupby(['Umidade']).size()
dataset.loc[dataset['Umidade'] == 200, 'Umidade'] = 70

# %%
dataset.groupby(['Umidade']).size()
# Out:
# Umidade
# 65.0    1
# 70.0    4
# 75.0    1
# 80.0    1
# 85.0    1
# 86.0    1
# 90.0    2
# 91.0    1
# 95.0    1
# dtype: int64

# %%
dataset['Umidade'].fillna(70, inplace= True)
dataset
# Out:
#    Aparencia  Temperatura  Umidade       Vento Jogar
# 0        sol         85.0     85.0       FALSO   nao
# 1        sol         80.0     90.0  VERDADEIRO   nao
# 2    nublado         83.0     86.0       FALSO   sim
# 3      chuva         70.0     70.0       FALSO   sim
# 4      chuva         68.0     80.0       FALSO   sim
# 5      chuva         65.0     70.0  VERDADEIRO   nao
# 6        sol         64.0     65.0  VERDADEIRO   sim
# 7        sol         73.5     95.0       FALSO   nao
# 8        sol         69.0     70.0       FALSO   sim
# 9      chuva         75.0     70.0         NaN   sim
# 10       sol         75.0     70.0  VERDADEIRO   sim
# 11   nublado         72.0     90.0  VERDADEIRO   sim
# 12   nublado         81.0     75.0       FALSO   sim
# 13     chuva         71.0     91.0  VERDADEIRO   nao

# %%
dataset.groupby(['Vento']).size()
# Out:
# Vento
# FALSO         7
# VERDADEIRO    6
# dtype: int64

# %%
dataset.fillna('FALSO', inplace= True)
dataset
# Out:
#    Aparencia  Temperatura  Umidade       Vento Jogar
# 0        sol         85.0     85.0       FALSO   nao
# 1        sol         80.0     90.0  VERDADEIRO   nao
# 2    nublado         83.0     86.0       FALSO   sim
# 3      chuva         70.0     70.0       FALSO   sim
# 4      chuva         68.0     80.0       FALSO   sim
# 5      chuva         65.0     70.0  VERDADEIRO   nao
# 6        sol         64.0     65.0  VERDADEIRO   sim
# 7        sol         73.5     95.0       FALSO   nao
# 8        sol         69.0     70.0       FALSO   sim
# 9      chuva         75.0     70.0       FALSO   sim
# 10       sol         75.0     70.0  VERDADEIRO   sim
# 11   nublado         72.0     90.0  VERDADEIRO   sim
# 12   nublado         81.0     75.0       FALSO   sim
# 13     chuva         71.0     91.0  VERDADEIRO   nao
